# %%
import numpy as np
import pandas as pd
import math

# %%
df = pd.read_csv('../datasets/pokemon.csv')

# %%
display(df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
lista_columnas = list(df.columns)

# %%
print(lista_columnas)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']

# %%
columns_newname = [element.replace(' ', '_')   for element in lista_columnas]

# %%
dic_rename_columns = {x : y for x,y in zip(lista_columnas, columns_newname)}

# %%
dic_rename_columns
# Out:
# {'#': '#',
#  'Name': 'Name',
#  'Type 1': 'Type_1',
#  'Type 2': 'Type_2',
#  'Total': 'Total',
#  'HP': 'HP',
#  'Attack': 'Attack',
#  'Defense': 'Defense',
#  'Sp. Atk': 'Sp._Atk',
#  'Sp. Def': 'Sp._Def',
#  'Speed': 'Speed',
#  'Generation': 'Generation',
#  'Legendary': 'Legendary'}

# %%
df_work = df.rename(columns = dic_rename_columns)

# %%
df_work
# Out:
#        #                   Name   Type_1  Type_2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.median(axis = 1)
# Out:
# 0       47.0
# 1       61.0
# 2       81.0
# 3       90.0
# 4       46.5
#        ...
# 795    100.0
# 796    110.0
# 797     95.0
# 798    105.0
# 799    100.0
# Length: 800, dtype: float64

# %%
df.Legendary
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795     True
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Legendary, Length: 800, dtype: bool

# %%
df.Attack.head(3)
# Out:
# 0    49
# 1    62
# 2    82
# Name: Attack, dtype: int64

# %%
df.HP.head(3)
# Out:
# 0    45
# 1    60
# 2    80
# Name: HP, dtype: int64

# %%
df.Defense.head(3)
# Out:
# 0    49
# 1    63
# 2    83
# Name: Defense, dtype: int64

# %%
df.loc[df.Attack & df.HP & df.Defense]['Type 1']
# Out:
# 33    Ground
# 60     Water
# 80      Rock
# 64      Fire
# 32    Ground
#        ...
# 0      Grass
# 32    Ground
# 0      Grass
# 0      Grass
# 64      Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df.loc[df.Attack & df.HP & df.Defense].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 33 to 64
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      449 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 82.0+ KB

# %%
df.loc[df.Attack & df.HP & df.Defense].columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 122.0+ KB

# %%
df_work.loc[(df_work.Type_1 == 'Fire') | (df_work.Legendary == True)]        # & df_work.Legendary is True
# Out:
#        #                       Name   Type_1  Type_2  Total  HP  Attack  \
# 4      4                 Charmander     Fire     NaN    309  39      52
# 5      5                 Charmeleon     Fire     NaN    405  58      64
# 6      6                  Charizard     Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X     Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634  78     104
# ..   ...                        ...      ...     ...    ...  ..     ...
# 795  719                    Diancie     Rock   Fairy    600  50     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700  50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799  721                  Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp._Atk  Sp._Def  Speed  Generation  Legendary
# ...

# %%
#display(df_work.loc[df_work.Type_1 == 'Fire'])
#display(df_work.Type_1.value_counts())
display(df_work.Type_2.value_counts())
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Rock        14
# Ghost       14
# Ice         14
# Water       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type_2, dtype: int64

# %%
df_work.Type_2.isna().value_counts()
df_work.Type_1.isna().value_counts()
# Out:
# False    800
# Name: Type_1, dtype: int64

# %%
df_work.tail(20)
# Out:
#        #                   Name   Type_1  Type_2  Total   HP  Attack  Defense  \
# 780  710  PumpkabooAverage Size    Ghost   Grass    335   49      66       70
# 781  710    PumpkabooSmall Size    Ghost   Grass    335   44      66       70
# 782  710    PumpkabooLarge Size    Ghost   Grass    335   54      66       70
# 783  710    PumpkabooSuper Size    Ghost   Grass    335   59      66       70
# 784  711  GourgeistAverage Size    Ghost   Grass    494   65      90      122
# 785  711    GourgeistSmall Size    Ghost   Grass    494   55      85      122
# 786  711    GourgeistLarge Size    Ghost   Grass    494   75      95      122
# 787  711    GourgeistSuper Size    Ghost   Grass    494   85     100      122
# 788  712               Bergmite      Ice     NaN    304   55      69       85
# 789  713                Avalugg      Ice     NaN    514   95     117      184
# 790  714                 Noibat   Flying  Dragon    245   40      30       35
# ...

# %%
df_work.iloc[6:15, 5:10]
# Out:
#     HP  Attack  Defense  Sp._Atk  Sp._Def
# 6   78      84       78      109       85
# 7   78     130      111      130       85
# 8   78     104       78      159      115
# 9   44      48       65       50       64
# 10  59      63       80       65       80
# 11  79      83      100       85      105
# 12  79     103      120      135      115
# 13  45      30       35       20       20
# 14  50      20       55       25       25

# %%
display(df_work.loc[(df_work.Legendary == True) & (df_work.Type_1 == 'Fire')])
# Out:
#        #       Name Type_1  Type_2  Total   HP  Attack  Defense  Sp._Atk  \
# 158  146    Moltres   Fire  Flying    580   90     100       90      125
# 263  244      Entei   Fire     NaN    580  115     115       85       90
# 270  250      Ho-oh   Fire  Flying    680  106     130       90      110
# 542  485    Heatran   Fire   Steel    600   91      90      106      130
# 799  721  Volcanion   Fire   Water    600   80     110      120      130
#
#      Sp._Def  Speed  Generation  Legendary
# 158       85     90           1       True
# 263       75    100           2       True
# 270      154     90           2       True
# 542      106     77           4       True
# 799       90     70           6       True

# %%
df_work.Type_2.loc[(df_work.Legendary == True)].value_counts()
# Out:
# Flying      13
# Psychic      5
# Fighting     4
# Dragon       4
# Ice          3
# Fire         3
# Fairy        2
# Water        1
# Ground       1
# Steel        1
# Ghost        1
# Electric     1
# Dark         1
# Name: Type_2, dtype: int64

# %%
df_work[['Type_1', 'Type_2']].loc[df_work.Legendary == True].value_counts()
# Out:
# Type_1    Type_2
# Dragon    Psychic     4
#           Ice         3
# Electric  Flying      3
# Dragon    Flying      2
# Rock      Fairy       2
# Fire      Flying      2
# Ground    Flying      2
# Ghost     Dragon      2
# Water     Dragon      1
# Grass     Fighting    1
# Dragon    Electric    1
#           Fire        1
#           Ground      1
# Fire      Steel       1
#           Water       1
# Grass     Flying      1
# Steel     Psychic     1
# Ground    Fire        1
# Ice       Flying      1
# Psychic   Dark        1
#           Fighting    1
#           Fire        1
#           Flying      1
#           Ghost       1
# Rock      Fighting    1
# Steel     Dragon      1
#           Fighting    1
# Dark      Flying      1
# dtype: int64

# %%
df_work.loc[(df_work.Type_1 == 'Electric') & (df_work.Type_2 == 'Flying')].shape
# Out:
# (5, 13)

# %%
df_work.loc[(df_work.Type_1 == 'Electric') & (df_work.Type_2 == 'Flying') & (df_work.Legendary == True)].shape
# Out:
# (3, 13)

# %%
df_work.loc[(df_work.Type_1 == 'Electric') & (df_work.Type_2 == 'Flying') & (df_work.Legendary == False)].shape
# Out:
# (2, 13)

# %%
math.gcd (2, 13)
# Out:
# 1
